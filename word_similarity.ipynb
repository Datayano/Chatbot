# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn.metrics.pairwise import cosine_similarity
import re
import numpy as np

# %%
from tqdm import tqdm
tqdm.pandas()

# %%
! python -m spacy download fr_core_news_sm
import fr_core_news_sm

nlp = fr_core_news_sm.load()
# Out:
# Collecting fr-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-3.7.0/fr_core_news_sm-3.7.0-py3-none-any.whl (16.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 52.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from fr-core-news-sm==3.7.0) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (4.66.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.10.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.17.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = "/content/drive/MyDrive/Paris 0924 - Data Analyst/Live_Coding/s13_nlp/text_similarity/"

# %%
df_ingredients = pd.read_csv(path + "ingredients_clean.csv" )

# %%
print(df_ingredients.head().to_markdown())
# Out:
# |    | id                       | name                                              | URL                                             | Description                                                                             |   Cooking time |   Preparation extra time per cover |   Covers count | ingredients                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             | ingredients_name                                                                          |
# |---:|:-------------------------|:--------------------------------------------------|:------------------------------------------------|:----------------------------------------------------------------------------------------|---------------:|-----------------------------------:|---------------:|:------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:------------------------------------------------------------------------------------------|
# |  0 | 6512f357488630000f1e3d65 | Crostini truite fumée, fromage frais & ciboulette | https://jow.fr/recipes/6512f357488630000f1e3d65 | Gourmands & frais, ces crostinis vont en régaler plus d'un !                            |              5 |                                  1 |              1 | [{'nom_ingred': 'Demi-baguette (précuite)', 'quantity': 0.25, 'unit': 'Pièce'}, {'nom_ingred': 'Truite fumée', 'quantity': 2, 'unit': 'Tranche'}, {'nom_ingred': 'Fromage frais', 'quantity': 2, 'unit': 'Cuillère à soupe'}, {'nom_ingred': 'Oignon rouge', 'quantity': 0.125, 'unit': 'Pièce'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}]                                                                                                                                                                                                     | Demi-baguette (précuite),Truite fumée,Fromage frais,Oignon rouge,Ciboulette               |
# |  1 | 653a3579d854b0000f9ab3cb | Loaded eggs fries                                 | https://jow.fr/recipes/653a3579d854b0000f9ab3cb | Des frites croustillantes recouvertes de fromage fondant, de bacon & d'un œuf au plat ! |             17 |                                  0 |              1 | [{'nom_ingred': 'Frites surgelées', 'quantity': 0.15, 'unit': 'Kilogramme'}, {'nom_ingred': 'Œuf', 'quantity': 1, 'unit': 'Pièce'}, {'nom_ingred': 'Lard (tranches)', 'quantity': 2, 'unit': 'Tranche'}, {'nom_ingred': 'Cheddar (tranches)', 'quantity': 2, 'unit': 'Tranche'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}]                                                                                                                                                                                                                      | Frites surgelées,Œuf,Lard (tranches),Cheddar (tranches),Ciboulette                        |
# |  2 | 60e464ab1315f60eae338281 | Rolls saumon & avocat                             | https://jow.fr/recipes/60e464ab1315f60eae338281 | Le genre d'apéritif qui disparaît en un clin d'œil !                                    |            nan |                                  3 |              1 | [{'nom_ingred': 'Fromage frais', 'quantity': 1, 'unit': 'Cuillère à soupe'}, {'nom_ingred': 'Citron jaune', 'quantity': 0.25, 'unit': 'Pièce'}, {'nom_ingred': 'Avocat', 'quantity': 0.25, 'unit': 'Pièce'}, {'nom_ingred': 'Saumon (fumé)', 'quantity': 0.5, 'unit': 'Tranche'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}]                                                                                                                                                                                                                     | Fromage frais,Citron jaune,Avocat,Saumon (fumé),Ciboulette                                |
# |  3 | 6318b9fe90de45667ed89c2b | Frites gratinées à la raclette & lardons          | https://jow.fr/recipes/6318b9fe90de45667ed89c2b | Anti-gourmands s’abstenir !                                                             |             22 |                                  3 |              1 | [{'nom_ingred': 'Frites surgelées', 'quantity': 0.2, 'unit': 'Kilogramme'}, {'nom_ingred': 'Raclette', 'quantity': 0.04, 'unit': 'Kilogramme'}, {'nom_ingred': 'Oignon rouge', 'quantity': 0.25, 'unit': 'Pièce'}, {'nom_ingred': 'Lardons', 'quantity': 0.075, 'unit': 'Kilogramme'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}]                                                                                                                                                                                                                | Frites surgelées,Raclette,Oignon rouge,Lardons,Ciboulette                                 |
# |  4 | 5a96e9fbc0a671001461681d | Pancakes de courgette                             | https://jow.fr/recipes/5a96e9fbc0a671001461681d | Les enfants vont adorer manger des légumes !                                            |              8 |                                  5 |              1 | [{'nom_ingred': 'Courgette', 'quantity': 0.2, 'unit': 'Kilogramme'}, {'nom_ingred': 'Ail', 'quantity': 0.25, 'unit': 'Gousse'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}, {'nom_ingred': 'Œuf', 'quantity': 1, 'unit': 'Pièce'}, {'nom_ingred': 'Farine de blé', 'quantity': 1, 'unit': 'Cuillère à soupe'}, {'nom_ingred': 'Chapelure', 'quantity': 1, 'unit': 'Cuillère à soupe'}, {'nom_ingred': 'Parmesan (morceaux)', 'quantity': 0.02, 'unit': 'Kilogramme'}, {'nom_ingred': 'Salade (Mélange)', 'quantity': 0.03, 'unit': 'Kilogramme'}] | Courgette,Ail,Ciboulette,Œuf,Farine de blé,Chapelure,Parmesan (morceaux),Salade (Mélange) |

# %%
print(df_ingredients.shape) #nbr de ligne
# Out:
# (1838, 9)

# %%
print(df_ingredients.id.nunique()) #nbr de recette
# Out:
# 1838

# %%
print(df_ingredients.head().to_markdown())
# Out:
# |    | id                       | name                                              | URL                                             | Description                                                                             |   Cooking time |   Preparation extra time per cover |   Covers count | ingredients                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             | ingredients_name                                                                          |
# |---:|:-------------------------|:--------------------------------------------------|:------------------------------------------------|:----------------------------------------------------------------------------------------|---------------:|-----------------------------------:|---------------:|:------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:------------------------------------------------------------------------------------------|
# |  0 | 6512f357488630000f1e3d65 | Crostini truite fumée, fromage frais & ciboulette | https://jow.fr/recipes/6512f357488630000f1e3d65 | Gourmands & frais, ces crostinis vont en régaler plus d'un !                            |              5 |                                  1 |              1 | [{'nom_ingred': 'Demi-baguette (précuite)', 'quantity': 0.25, 'unit': 'Pièce'}, {'nom_ingred': 'Truite fumée', 'quantity': 2, 'unit': 'Tranche'}, {'nom_ingred': 'Fromage frais', 'quantity': 2, 'unit': 'Cuillère à soupe'}, {'nom_ingred': 'Oignon rouge', 'quantity': 0.125, 'unit': 'Pièce'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}]                                                                                                                                                                                                     | Demi-baguette (précuite),Truite fumée,Fromage frais,Oignon rouge,Ciboulette               |
# |  1 | 653a3579d854b0000f9ab3cb | Loaded eggs fries                                 | https://jow.fr/recipes/653a3579d854b0000f9ab3cb | Des frites croustillantes recouvertes de fromage fondant, de bacon & d'un œuf au plat ! |             17 |                                  0 |              1 | [{'nom_ingred': 'Frites surgelées', 'quantity': 0.15, 'unit': 'Kilogramme'}, {'nom_ingred': 'Œuf', 'quantity': 1, 'unit': 'Pièce'}, {'nom_ingred': 'Lard (tranches)', 'quantity': 2, 'unit': 'Tranche'}, {'nom_ingred': 'Cheddar (tranches)', 'quantity': 2, 'unit': 'Tranche'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}]                                                                                                                                                                                                                      | Frites surgelées,Œuf,Lard (tranches),Cheddar (tranches),Ciboulette                        |
# |  2 | 60e464ab1315f60eae338281 | Rolls saumon & avocat                             | https://jow.fr/recipes/60e464ab1315f60eae338281 | Le genre d'apéritif qui disparaît en un clin d'œil !                                    |            nan |                                  3 |              1 | [{'nom_ingred': 'Fromage frais', 'quantity': 1, 'unit': 'Cuillère à soupe'}, {'nom_ingred': 'Citron jaune', 'quantity': 0.25, 'unit': 'Pièce'}, {'nom_ingred': 'Avocat', 'quantity': 0.25, 'unit': 'Pièce'}, {'nom_ingred': 'Saumon (fumé)', 'quantity': 0.5, 'unit': 'Tranche'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}]                                                                                                                                                                                                                     | Fromage frais,Citron jaune,Avocat,Saumon (fumé),Ciboulette                                |
# |  3 | 6318b9fe90de45667ed89c2b | Frites gratinées à la raclette & lardons          | https://jow.fr/recipes/6318b9fe90de45667ed89c2b | Anti-gourmands s’abstenir !                                                             |             22 |                                  3 |              1 | [{'nom_ingred': 'Frites surgelées', 'quantity': 0.2, 'unit': 'Kilogramme'}, {'nom_ingred': 'Raclette', 'quantity': 0.04, 'unit': 'Kilogramme'}, {'nom_ingred': 'Oignon rouge', 'quantity': 0.25, 'unit': 'Pièce'}, {'nom_ingred': 'Lardons', 'quantity': 0.075, 'unit': 'Kilogramme'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}]                                                                                                                                                                                                                | Frites surgelées,Raclette,Oignon rouge,Lardons,Ciboulette                                 |
# |  4 | 5a96e9fbc0a671001461681d | Pancakes de courgette                             | https://jow.fr/recipes/5a96e9fbc0a671001461681d | Les enfants vont adorer manger des légumes !                                            |              8 |                                  5 |              1 | [{'nom_ingred': 'Courgette', 'quantity': 0.2, 'unit': 'Kilogramme'}, {'nom_ingred': 'Ail', 'quantity': 0.25, 'unit': 'Gousse'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}, {'nom_ingred': 'Œuf', 'quantity': 1, 'unit': 'Pièce'}, {'nom_ingred': 'Farine de blé', 'quantity': 1, 'unit': 'Cuillère à soupe'}, {'nom_ingred': 'Chapelure', 'quantity': 1, 'unit': 'Cuillère à soupe'}, {'nom_ingred': 'Parmesan (morceaux)', 'quantity': 0.02, 'unit': 'Kilogramme'}, {'nom_ingred': 'Salade (Mélange)', 'quantity': 0.03, 'unit': 'Kilogramme'}] | Courgette,Ail,Ciboulette,Œuf,Farine de blé,Chapelure,Parmesan (morceaux),Salade (Mélange) |

# %%
#pas de nan pour les colonnes utilisé par le model
print(df_ingredients.isna().sum())
# Out:
# id                                    0
# name                                  0
# URL                                   0
# Description                           0
# Cooking time                        126
# Preparation extra time per cover     97
# Covers count                          0
# ingredients                           0
# ingredients_name                      0
# dtype: int64

# %%
#on va créer une colonne contenant toutes les inforations texte nécessaire pour faire la recommandation par mot clé


# les colonnes intéressantes sont : name, description, ingredients_name

df_ingredients['all_text'] = df_ingredients['name'] + " ; " + df_ingredients['Description'] + " ; " + df_ingredients['ingredients_name']

# %%
print(df_ingredients.head().to_markdown())
# Out:
# |    | id                       | name                                              | URL                                             | Description                                                                             |   Cooking time |   Preparation extra time per cover |   Covers count | ingredients                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             | ingredients_name                                                                          | all_text                                                                                                                                                                                       |
# |---:|:-------------------------|:--------------------------------------------------|:------------------------------------------------|:----------------------------------------------------------------------------------------|---------------:|-----------------------------------:|---------------:|:------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:------------------------------------------------------------------------------------------|:-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  0 | 6512f357488630000f1e3d65 | Crostini truite fumée, fromage frais & ciboulette | https://jow.fr/recipes/6512f357488630000f1e3d65 | Gourmands & frais, ces crostinis vont en régaler plus d'un !                            |              5 |                                  1 |              1 | [{'nom_ingred': 'Demi-baguette (précuite)', 'quantity': 0.25, 'unit': 'Pièce'}, {'nom_ingred': 'Truite fumée', 'quantity': 2, 'unit': 'Tranche'}, {'nom_ingred': 'Fromage frais', 'quantity': 2, 'unit': 'Cuillère à soupe'}, {'nom_ingred': 'Oignon rouge', 'quantity': 0.125, 'unit': 'Pièce'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}]                                                                                                                                                                                                     | Demi-baguette (précuite),Truite fumée,Fromage frais,Oignon rouge,Ciboulette               | Crostini truite fumée, fromage frais & ciboulette ; Gourmands & frais, ces crostinis vont en régaler plus d'un ! ; Demi-baguette (précuite),Truite fumée,Fromage frais,Oignon rouge,Ciboulette |
# |  1 | 653a3579d854b0000f9ab3cb | Loaded eggs fries                                 | https://jow.fr/recipes/653a3579d854b0000f9ab3cb | Des frites croustillantes recouvertes de fromage fondant, de bacon & d'un œuf au plat ! |             17 |                                  0 |              1 | [{'nom_ingred': 'Frites surgelées', 'quantity': 0.15, 'unit': 'Kilogramme'}, {'nom_ingred': 'Œuf', 'quantity': 1, 'unit': 'Pièce'}, {'nom_ingred': 'Lard (tranches)', 'quantity': 2, 'unit': 'Tranche'}, {'nom_ingred': 'Cheddar (tranches)', 'quantity': 2, 'unit': 'Tranche'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}]                                                                                                                                                                                                                      | Frites surgelées,Œuf,Lard (tranches),Cheddar (tranches),Ciboulette                        | Loaded eggs fries ; Des frites croustillantes recouvertes de fromage fondant, de bacon & d'un œuf au plat ! ; Frites surgelées,Œuf,Lard (tranches),Cheddar (tranches),Ciboulette               |
# |  2 | 60e464ab1315f60eae338281 | Rolls saumon & avocat                             | https://jow.fr/recipes/60e464ab1315f60eae338281 | Le genre d'apéritif qui disparaît en un clin d'œil !                                    |            nan |                                  3 |              1 | [{'nom_ingred': 'Fromage frais', 'quantity': 1, 'unit': 'Cuillère à soupe'}, {'nom_ingred': 'Citron jaune', 'quantity': 0.25, 'unit': 'Pièce'}, {'nom_ingred': 'Avocat', 'quantity': 0.25, 'unit': 'Pièce'}, {'nom_ingred': 'Saumon (fumé)', 'quantity': 0.5, 'unit': 'Tranche'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}]                                                                                                                                                                                                                     | Fromage frais,Citron jaune,Avocat,Saumon (fumé),Ciboulette                                | Rolls saumon & avocat ; Le genre d'apéritif qui disparaît en un clin d'œil ! ; Fromage frais,Citron jaune,Avocat,Saumon (fumé),Ciboulette                                                      |
# |  3 | 6318b9fe90de45667ed89c2b | Frites gratinées à la raclette & lardons          | https://jow.fr/recipes/6318b9fe90de45667ed89c2b | Anti-gourmands s’abstenir !                                                             |             22 |                                  3 |              1 | [{'nom_ingred': 'Frites surgelées', 'quantity': 0.2, 'unit': 'Kilogramme'}, {'nom_ingred': 'Raclette', 'quantity': 0.04, 'unit': 'Kilogramme'}, {'nom_ingred': 'Oignon rouge', 'quantity': 0.25, 'unit': 'Pièce'}, {'nom_ingred': 'Lardons', 'quantity': 0.075, 'unit': 'Kilogramme'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}]                                                                                                                                                                                                                | Frites surgelées,Raclette,Oignon rouge,Lardons,Ciboulette                                 | Frites gratinées à la raclette & lardons ; Anti-gourmands s’abstenir ! ; Frites surgelées,Raclette,Oignon rouge,Lardons,Ciboulette                                                             |
# |  4 | 5a96e9fbc0a671001461681d | Pancakes de courgette                             | https://jow.fr/recipes/5a96e9fbc0a671001461681d | Les enfants vont adorer manger des légumes !                                            |              8 |                                  5 |              1 | [{'nom_ingred': 'Courgette', 'quantity': 0.2, 'unit': 'Kilogramme'}, {'nom_ingred': 'Ail', 'quantity': 0.25, 'unit': 'Gousse'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}, {'nom_ingred': 'Œuf', 'quantity': 1, 'unit': 'Pièce'}, {'nom_ingred': 'Farine de blé', 'quantity': 1, 'unit': 'Cuillère à soupe'}, {'nom_ingred': 'Chapelure', 'quantity': 1, 'unit': 'Cuillère à soupe'}, {'nom_ingred': 'Parmesan (morceaux)', 'quantity': 0.02, 'unit': 'Kilogramme'}, {'nom_ingred': 'Salade (Mélange)', 'quantity': 0.03, 'unit': 'Kilogramme'}] | Courgette,Ail,Ciboulette,Œuf,Farine de blé,Chapelure,Parmesan (morceaux),Salade (Mélange) | Pancakes de courgette ; Les enfants vont adorer manger des légumes ! ; Courgette,Ail,Ciboulette,Œuf,Farine de blé,Chapelure,Parmesan (morceaux),Salade (Mélange)                               |

# %%
def clean_text(text):
    # rendre tous le text en minuscule : par ex "Good" et "good" deviennent equivalent
    text = text.lower()


    #a appliquer la grammaire à votre text
    text_spacy = nlp(text)
    # definir une chaine vide permettant de stoker les token séléctionné
    text_clean = ""
    #parcourir chaque token du tetx
    for token in text_spacy:
        #but est d'enlever les token qui ne sert pas à grand chose
        # considérer les token alphabethique , enlever les stopwrods , enlever digit et ponctuation
        #aussi contenant au moins 2 charactere
        if token.is_alpha and token.is_stop == False and token.like_num == False:
            #print(token, token.tag_, token.lemma_)

            text_clean += token.lemma_ +  " "
    # enlever les espace en double
    text_clean = re.sub("\s+", " ", text_clean)
    return text_clean

# %%
ex = df_ingredients.loc[1,"all_text"]
print(ex)
text_clean = clean_text(ex)
print(text_clean)
# Out:
# Loaded eggs fries ; Des frites croustillantes recouvertes de fromage fondant, de bacon & d'un œuf au plat ! ; Frites surgelées,Œuf,Lard (tranches),Cheddar (tranches),Ciboulette
# loaded eggs frie frite croustillant recouverte fromage fondre bacon œuf plat frit surgeler œuf lard

# %%
df_ingredients['all_text_clean'] = df_ingredients['all_text'].progress_apply(clean_text)
# Out:
# 100%|██████████| 1838/1838 [00:35<00:00, 51.07it/s]

# %%
print(df_ingredients.head().to_markdown())
# Out:
# |    | id                       | name                                              | URL                                             | Description                                                                             |   Cooking time |   Preparation extra time per cover |   Covers count | ingredients                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             | ingredients_name                                                                          | all_text                                                                                                                                                                                       | all_text_clean                                                                                                            |
# |---:|:-------------------------|:--------------------------------------------------|:------------------------------------------------|:----------------------------------------------------------------------------------------|---------------:|-----------------------------------:|---------------:|:------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:------------------------------------------------------------------------------------------|:-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:--------------------------------------------------------------------------------------------------------------------------|
# |  0 | 6512f357488630000f1e3d65 | Crostini truite fumée, fromage frais & ciboulette | https://jow.fr/recipes/6512f357488630000f1e3d65 | Gourmands & frais, ces crostinis vont en régaler plus d'un !                            |              5 |                                  1 |              1 | [{'nom_ingred': 'Demi-baguette (précuite)', 'quantity': 0.25, 'unit': 'Pièce'}, {'nom_ingred': 'Truite fumée', 'quantity': 2, 'unit': 'Tranche'}, {'nom_ingred': 'Fromage frais', 'quantity': 2, 'unit': 'Cuillère à soupe'}, {'nom_ingred': 'Oignon rouge', 'quantity': 0.125, 'unit': 'Pièce'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}]                                                                                                                                                                                                     | Demi-baguette (précuite),Truite fumée,Fromage frais,Oignon rouge,Ciboulette               | Crostini truite fumée, fromage frais & ciboulette ; Gourmands & frais, ces crostinis vont en régaler plus d'un ! ; Demi-baguette (précuite),Truite fumée,Fromage frais,Oignon rouge,Ciboulette | crostini truit fumer fromage frais ciboulette gourmand frais crostini régaler fumer fromage frais oignon rouge ciboulette |
# |  1 | 653a3579d854b0000f9ab3cb | Loaded eggs fries                                 | https://jow.fr/recipes/653a3579d854b0000f9ab3cb | Des frites croustillantes recouvertes de fromage fondant, de bacon & d'un œuf au plat ! |             17 |                                  0 |              1 | [{'nom_ingred': 'Frites surgelées', 'quantity': 0.15, 'unit': 'Kilogramme'}, {'nom_ingred': 'Œuf', 'quantity': 1, 'unit': 'Pièce'}, {'nom_ingred': 'Lard (tranches)', 'quantity': 2, 'unit': 'Tranche'}, {'nom_ingred': 'Cheddar (tranches)', 'quantity': 2, 'unit': 'Tranche'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}]                                                                                                                                                                                                                      | Frites surgelées,Œuf,Lard (tranches),Cheddar (tranches),Ciboulette                        | Loaded eggs fries ; Des frites croustillantes recouvertes de fromage fondant, de bacon & d'un œuf au plat ! ; Frites surgelées,Œuf,Lard (tranches),Cheddar (tranches),Ciboulette               | loaded eggs frie frite croustillant recouverte fromage fondre bacon œuf plat frit surgeler œuf lard                       |
# |  2 | 60e464ab1315f60eae338281 | Rolls saumon & avocat                             | https://jow.fr/recipes/60e464ab1315f60eae338281 | Le genre d'apéritif qui disparaît en un clin d'œil !                                    |            nan |                                  3 |              1 | [{'nom_ingred': 'Fromage frais', 'quantity': 1, 'unit': 'Cuillère à soupe'}, {'nom_ingred': 'Citron jaune', 'quantity': 0.25, 'unit': 'Pièce'}, {'nom_ingred': 'Avocat', 'quantity': 0.25, 'unit': 'Pièce'}, {'nom_ingred': 'Saumon (fumé)', 'quantity': 0.5, 'unit': 'Tranche'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}]                                                                                                                                                                                                                     | Fromage frais,Citron jaune,Avocat,Saumon (fumé),Ciboulette                                | Rolls saumon & avocat ; Le genre d'apéritif qui disparaît en un clin d'œil ! ; Fromage frais,Citron jaune,Avocat,Saumon (fumé),Ciboulette                                                      | roll saumon avocat genre apéritif disparaître clin œil fromage frais citron jaune avocat saumon                           |
# |  3 | 6318b9fe90de45667ed89c2b | Frites gratinées à la raclette & lardons          | https://jow.fr/recipes/6318b9fe90de45667ed89c2b | Anti-gourmands s’abstenir !                                                             |             22 |                                  3 |              1 | [{'nom_ingred': 'Frites surgelées', 'quantity': 0.2, 'unit': 'Kilogramme'}, {'nom_ingred': 'Raclette', 'quantity': 0.04, 'unit': 'Kilogramme'}, {'nom_ingred': 'Oignon rouge', 'quantity': 0.25, 'unit': 'Pièce'}, {'nom_ingred': 'Lardons', 'quantity': 0.075, 'unit': 'Kilogramme'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}]                                                                                                                                                                                                                | Frites surgelées,Raclette,Oignon rouge,Lardons,Ciboulette                                 | Frites gratinées à la raclette & lardons ; Anti-gourmands s’abstenir ! ; Frites surgelées,Raclette,Oignon rouge,Lardons,Ciboulette                                                             | frit gratiner raclette lardon abstenir frit surgeler raclette oignon rouge lardon ciboulette                              |
# |  4 | 5a96e9fbc0a671001461681d | Pancakes de courgette                             | https://jow.fr/recipes/5a96e9fbc0a671001461681d | Les enfants vont adorer manger des légumes !                                            |              8 |                                  5 |              1 | [{'nom_ingred': 'Courgette', 'quantity': 0.2, 'unit': 'Kilogramme'}, {'nom_ingred': 'Ail', 'quantity': 0.25, 'unit': 'Gousse'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}, {'nom_ingred': 'Œuf', 'quantity': 1, 'unit': 'Pièce'}, {'nom_ingred': 'Farine de blé', 'quantity': 1, 'unit': 'Cuillère à soupe'}, {'nom_ingred': 'Chapelure', 'quantity': 1, 'unit': 'Cuillère à soupe'}, {'nom_ingred': 'Parmesan (morceaux)', 'quantity': 0.02, 'unit': 'Kilogramme'}, {'nom_ingred': 'Salade (Mélange)', 'quantity': 0.03, 'unit': 'Kilogramme'}] | Courgette,Ail,Ciboulette,Œuf,Farine de blé,Chapelure,Parmesan (morceaux),Salade (Mélange) | Pancakes de courgette ; Les enfants vont adorer manger des légumes ! ; Courgette,Ail,Ciboulette,Œuf,Farine de blé,Chapelure,Parmesan (morceaux),Salade (Mélange)                               | pancaker courgette enfant adorer manger légume courgette ail ciboulette œuf farine blé chapelure parmesan mélange         |

# %%
print(df_ingredients.head().to_markdown())
# Out:
# |    | id                       | name                                              | URL                                             | Description                                                                             |   Cooking time |   Preparation extra time per cover |   Covers count | ingredients                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             | ingredients_name                                                                          | all_text                                                                                                                                                                                       | all_text_clean                                                                                                            |
# |---:|:-------------------------|:--------------------------------------------------|:------------------------------------------------|:----------------------------------------------------------------------------------------|---------------:|-----------------------------------:|---------------:|:------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:------------------------------------------------------------------------------------------|:-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:--------------------------------------------------------------------------------------------------------------------------|
# |  0 | 6512f357488630000f1e3d65 | Crostini truite fumée, fromage frais & ciboulette | https://jow.fr/recipes/6512f357488630000f1e3d65 | Gourmands & frais, ces crostinis vont en régaler plus d'un !                            |              5 |                                  1 |              1 | [{'nom_ingred': 'Demi-baguette (précuite)', 'quantity': 0.25, 'unit': 'Pièce'}, {'nom_ingred': 'Truite fumée', 'quantity': 2, 'unit': 'Tranche'}, {'nom_ingred': 'Fromage frais', 'quantity': 2, 'unit': 'Cuillère à soupe'}, {'nom_ingred': 'Oignon rouge', 'quantity': 0.125, 'unit': 'Pièce'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}]                                                                                                                                                                                                     | Demi-baguette (précuite),Truite fumée,Fromage frais,Oignon rouge,Ciboulette               | Crostini truite fumée, fromage frais & ciboulette ; Gourmands & frais, ces crostinis vont en régaler plus d'un ! ; Demi-baguette (précuite),Truite fumée,Fromage frais,Oignon rouge,Ciboulette | crostini truit fumer fromage frais ciboulette gourmand frais crostini régaler fumer fromage frais oignon rouge ciboulette |
# |  1 | 653a3579d854b0000f9ab3cb | Loaded eggs fries                                 | https://jow.fr/recipes/653a3579d854b0000f9ab3cb | Des frites croustillantes recouvertes de fromage fondant, de bacon & d'un œuf au plat ! |             17 |                                  0 |              1 | [{'nom_ingred': 'Frites surgelées', 'quantity': 0.15, 'unit': 'Kilogramme'}, {'nom_ingred': 'Œuf', 'quantity': 1, 'unit': 'Pièce'}, {'nom_ingred': 'Lard (tranches)', 'quantity': 2, 'unit': 'Tranche'}, {'nom_ingred': 'Cheddar (tranches)', 'quantity': 2, 'unit': 'Tranche'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}]                                                                                                                                                                                                                      | Frites surgelées,Œuf,Lard (tranches),Cheddar (tranches),Ciboulette                        | Loaded eggs fries ; Des frites croustillantes recouvertes de fromage fondant, de bacon & d'un œuf au plat ! ; Frites surgelées,Œuf,Lard (tranches),Cheddar (tranches),Ciboulette               | loaded eggs frie frite croustillant recouverte fromage fondre bacon œuf plat frit surgeler œuf lard                       |
# |  2 | 60e464ab1315f60eae338281 | Rolls saumon & avocat                             | https://jow.fr/recipes/60e464ab1315f60eae338281 | Le genre d'apéritif qui disparaît en un clin d'œil !                                    |            nan |                                  3 |              1 | [{'nom_ingred': 'Fromage frais', 'quantity': 1, 'unit': 'Cuillère à soupe'}, {'nom_ingred': 'Citron jaune', 'quantity': 0.25, 'unit': 'Pièce'}, {'nom_ingred': 'Avocat', 'quantity': 0.25, 'unit': 'Pièce'}, {'nom_ingred': 'Saumon (fumé)', 'quantity': 0.5, 'unit': 'Tranche'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}]                                                                                                                                                                                                                     | Fromage frais,Citron jaune,Avocat,Saumon (fumé),Ciboulette                                | Rolls saumon & avocat ; Le genre d'apéritif qui disparaît en un clin d'œil ! ; Fromage frais,Citron jaune,Avocat,Saumon (fumé),Ciboulette                                                      | roll saumon avocat genre apéritif disparaître clin œil fromage frais citron jaune avocat saumon                           |
# |  3 | 6318b9fe90de45667ed89c2b | Frites gratinées à la raclette & lardons          | https://jow.fr/recipes/6318b9fe90de45667ed89c2b | Anti-gourmands s’abstenir !                                                             |             22 |                                  3 |              1 | [{'nom_ingred': 'Frites surgelées', 'quantity': 0.2, 'unit': 'Kilogramme'}, {'nom_ingred': 'Raclette', 'quantity': 0.04, 'unit': 'Kilogramme'}, {'nom_ingred': 'Oignon rouge', 'quantity': 0.25, 'unit': 'Pièce'}, {'nom_ingred': 'Lardons', 'quantity': 0.075, 'unit': 'Kilogramme'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}]                                                                                                                                                                                                                | Frites surgelées,Raclette,Oignon rouge,Lardons,Ciboulette                                 | Frites gratinées à la raclette & lardons ; Anti-gourmands s’abstenir ! ; Frites surgelées,Raclette,Oignon rouge,Lardons,Ciboulette                                                             | frit gratiner raclette lardon abstenir frit surgeler raclette oignon rouge lardon ciboulette                              |
# |  4 | 5a96e9fbc0a671001461681d | Pancakes de courgette                             | https://jow.fr/recipes/5a96e9fbc0a671001461681d | Les enfants vont adorer manger des légumes !                                            |              8 |                                  5 |              1 | [{'nom_ingred': 'Courgette', 'quantity': 0.2, 'unit': 'Kilogramme'}, {'nom_ingred': 'Ail', 'quantity': 0.25, 'unit': 'Gousse'}, {'nom_ingred': 'Ciboulette', 'quantity': 0.1, 'unit': 'Bouquet'}, {'nom_ingred': 'Œuf', 'quantity': 1, 'unit': 'Pièce'}, {'nom_ingred': 'Farine de blé', 'quantity': 1, 'unit': 'Cuillère à soupe'}, {'nom_ingred': 'Chapelure', 'quantity': 1, 'unit': 'Cuillère à soupe'}, {'nom_ingred': 'Parmesan (morceaux)', 'quantity': 0.02, 'unit': 'Kilogramme'}, {'nom_ingred': 'Salade (Mélange)', 'quantity': 0.03, 'unit': 'Kilogramme'}] | Courgette,Ail,Ciboulette,Œuf,Farine de blé,Chapelure,Parmesan (morceaux),Salade (Mélange) | Pancakes de courgette ; Les enfants vont adorer manger des légumes ! ; Courgette,Ail,Ciboulette,Œuf,Farine de blé,Chapelure,Parmesan (morceaux),Salade (Mélange)                               | pancaker courgette enfant adorer manger légume courgette ail ciboulette œuf farine blé chapelure parmesan mélange         |

# %%
tfidf = TfidfVectorizer()

# %%
X_tfidf = tfidf.fit_transform(df_ingredients.all_text_clean)

# %%
cos_sim = cosine_similarity(X_tfidf,X_tfidf)

# %%
cos_sim
# Out:
# array([[1.        , 0.04957372, 0.08244531, ..., 0.04768244, 0.02957583,
#         0.02988163],
#        [0.04957372, 1.        , 0.02797276, ..., 0.01932518, 0.0195348 ,
#         0.        ],
#        [0.08244531, 0.02797276, 1.        , ..., 0.01100637, 0.01112575,
#         0.01124079],
#        ...,
#        [0.04768244, 0.01932518, 0.01100637, ..., 1.        , 0.04401421,
#         0.02649913],
#        [0.02957583, 0.0195348 , 0.01112575, ..., 0.04401421, 1.        ,
#         0.25199356],
#        [0.02988163, 0.        , 0.01124079, ..., 0.02649913, 0.25199356,
#         1.        ]])

# %%
#quelle recommandation ppour
#"Rolls saumon & avocat"
input_ = "Rolls saumon & avocat"
info_input = df_ingredients[df_ingredients.name== input_]
indice_input = info_input.index[0]
print(indice_input)
# Out:
# 2

# %%
scores = cos_sim[indice_input]
max_reco = 5
indices_reco = np.argsort(scores)[::-1][1:max_reco + 1]
print(indices_reco)
df_reco = df_ingredients.iloc[indices_reco]
print(df_reco.head().to_markdown())
# Out:
# [1127 1102 1179 1280  831]
# |      | id                       | name                        | URL                                             | Description                                                                        |   Cooking time |   Preparation extra time per cover |   Covers count | ingredients                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  | ingredients_name                                                                                             | all_text                                                                                                                                                                                            | all_text_clean                                                                                                            |
# |-----:|:-------------------------|:----------------------------|:------------------------------------------------|:-----------------------------------------------------------------------------------|---------------:|-----------------------------------:|---------------:|:-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:-------------------------------------------------------------------------------------------------------------|:----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:--------------------------------------------------------------------------------------------------------------------------|
# | 1127 | 5eea069127b0405273d28f5f | Salade avocat & saumon      | https://jow.fr/recipes/5eea069127b0405273d28f5f | On ne se lassera jamais du combo avocat-saumon !                                   |              0 |                                  1 |              1 | [{'nom_ingred': 'Salade (Mélange)', 'quantity': 2, 'unit': 'Poignée'}, {'nom_ingred': 'Avocat', 'quantity': 0.5, 'unit': 'Pièce'}, {'nom_ingred': 'Saumon (cru)', 'quantity': 1, 'unit': 'Pièce'}, {'nom_ingred': 'Citron jaune', 'quantity': 0.25, 'unit': 'Pièce'}, {'nom_ingred': "Moutarde à l'ancienne", 'quantity': 0.5, 'unit': 'Cuillère à café'}]                                                                                                                                                                                                                   | Salade (Mélange),Avocat,Saumon (cru),Citron jaune,Moutarde à l'ancienne                                      | Salade avocat & saumon ; On ne se lassera jamais du combo avocat-saumon ! ; Salade (Mélange),Avocat,Saumon (cru),Citron jaune,Moutarde à l'ancienne                                                 | salad avocat saumon lasser jamais combo avocat saumon salad saumon jaune moutarde ancien                                  |
# | 1102 | 5cb456b127cedb1920ffe7ee | Pizza saumon avocat         | https://jow.fr/recipes/5cb456b127cedb1920ffe7ee | Du saumon sur une pizza ? Oui, et plutôt deux fois qu'une !                        |              8 |                                  1 |              2 | [{'nom_ingred': 'Pâte à pizza', 'quantity': 0.5, 'unit': 'Pièce'}, {'nom_ingred': 'Avocat', 'quantity': 0.5, 'unit': 'Pièce'}, {'nom_ingred': 'Saumon (fumé)', 'quantity': 2, 'unit': 'Tranche'}, {'nom_ingred': 'Fromage frais', 'quantity': 0.04, 'unit': 'Kilogramme'}, {'nom_ingred': 'Salade (roquette)', 'quantity': 1, 'unit': 'Poignée'}, {'nom_ingred': 'Citron jaune', 'quantity': 0.25, 'unit': 'Pièce'}]                                                                                                                                                         | Pâte à pizza,Avocat,Saumon (fumé),Fromage frais,Salade (roquette),Citron jaune                               | Pizza saumon avocat ; Du saumon sur une pizza ? Oui, et plutôt deux fois qu'une ! ; Pâte à pizza,Avocat,Saumon (fumé),Fromage frais,Salade (roquette),Citron jaune                                  | pizza saumon avocat saumon pizza oui fois pât pizza avocat saumon frais salad jaune                                       |
# | 1179 | 5b83bbec68ec900004109fef | Salade saumon mangue avocat | https://jow.fr/recipes/5b83bbec68ec900004109fef | Assouvit les envies de fraîcheur très très rapidement.                             |              0 |                                  4 |              1 | [{'nom_ingred': 'Saumon (fumé)', 'quantity': 2, 'unit': 'Tranche'}, {'nom_ingred': 'Mangue', 'quantity': 0.25, 'unit': 'Pièce'}, {'nom_ingred': 'Épinard (frais)', 'quantity': 2, 'unit': 'Poignée'}, {'nom_ingred': 'Gingembre (frais)', 'quantity': 1, 'unit': 'Centimètre'}, {'nom_ingred': 'Sauce soja salée', 'quantity': 1, 'unit': 'Cuillère à soupe'}, {'nom_ingred': 'Avocat', 'quantity': 0.5, 'unit': 'Pièce'}, {'nom_ingred': 'Citron vert', 'quantity': 0.5, 'unit': 'Pièce'}, {'nom_ingred': 'Graines de sésame', 'quantity': 0.5, 'unit': 'Cuillère à café'}] | Saumon (fumé),Mangue,Épinard (frais),Gingembre (frais),Sauce soja salée,Avocat,Citron vert,Graines de sésame | Salade saumon mangue avocat ; Assouvit les envies de fraîcheur très très rapidement. ; Saumon (fumé),Mangue,Épinard (frais),Gingembre (frais),Sauce soja salée,Avocat,Citron vert,Graines de sésame | salad saumon mangue avocat assouvir envie fraîcheur rapidement saumon épinard soja saler avocat citron vert graine sésame |
# | 1280 | 5b842ff02587e20004f7c5b2 | Wrap Saumon                 | https://jow.fr/recipes/5b842ff02587e20004f7c5b2 | Recette express pour un repas sur le pouce                                         |              0 |                                  0 |              1 | [{'nom_ingred': 'Saumon (fumé)', 'quantity': 2, 'unit': 'Tranche'}, {'nom_ingred': 'Tortilla (blé)', 'quantity': 1, 'unit': 'Pièce'}, {'nom_ingred': 'Concombre', 'quantity': 0.1, 'unit': 'Pièce'}, {'nom_ingred': 'Fromage frais', 'quantity': 0.04, 'unit': 'Kilogramme'}, {'nom_ingred': 'Épinard (frais)', 'quantity': 0.5, 'unit': 'Poignée'}, {'nom_ingred': 'Citron jaune', 'quantity': 0.125, 'unit': 'Pièce'}]                                                                                                                                                     | Saumon (fumé),Tortilla (blé),Concombre,Fromage frais,Épinard (frais),Citron jaune                            | Wrap Saumon ; Recette express pour un repas sur le pouce ; Saumon (fumé),Tortilla (blé),Concombre,Fromage frais,Épinard (frais),Citron jaune                                                        | wrap saumon recette express repas pouce saumon fromage frais épinard jaune                                                |
# |  831 | 5eb1a7de223ab658d252f091 | Saumon & asperges rôtis     | https://jow.fr/recipes/5eb1a7de223ab658d252f091 | Le genre de dîner qu'on aime : on met tout au four et on attend que ce soit cuit ! |             27 |                                  1 |              1 | [{'nom_ingred': 'Saumon (frais)', 'quantity': 1, 'unit': 'Pièce'}, {'nom_ingred': 'Asperges vertes (fraîches)', 'quantity': 0.25, 'unit': 'Kilogramme'}, {'nom_ingred': 'Citron jaune', 'quantity': 0.125, 'unit': 'Pièce'}]                                                                                                                                                                                                                                                                                                                                                 | Saumon (frais),Asperges vertes (fraîches),Citron jaune                                                       | Saumon & asperges rôtis ; Le genre de dîner qu'on aime : on met tout au four et on attend que ce soit cuit ! ; Saumon (frais),Asperges vertes (fraîches),Citron jaune                               | saumon asperge rôtir genre dîner aimer mettre four attendre cuit saumon vert jaune                                        |

# %% [markdown]
# # embedding models

# %%
#créer en fonction
from sentence_transformers import SentenceTransformer

# 1. Load a pretrained Sentence Transformer model
model = SentenceTransformer("all-MiniLM-L6-v2")

# %% [markdown]
# # Test app

# %%
print(type(response["answer"]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(type(response["answer"]))
#
# NameError: name 'response' is not defined
